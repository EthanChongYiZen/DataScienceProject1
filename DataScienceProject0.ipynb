# %% [markdown]
# ### Steps
# 1. Import the data
# 2. Clean the data
# 3. Split the data into training/test sets
# 4. Create a model
# 5. Train the model
# 6. Make Predictions
# 7. Evualuate and Improve

# %% [markdown]
# Title: Music data ( made up data )

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import joblib
from sklearn import tree

music_data = pd.read_csv('music.csv')
music_data
# Out:
#     age  gender      genre
# 0    20       1     HipHop
# 1    23       1     HipHop
# 2    25       1     HipHop
# 3    26       1       Jazz
# 4    29       1       Jazz
# 5    30       1       Jazz
# 6    31       1  Classical
# 7    33       1  Classical
# 8    37       1  Classical
# 9    20       0      Dance
# 10   21       0      Dance
# 11   25       0      Dance
# 12   26       0   Acoustic
# 13   27       0   Acoustic
# 14   30       0   Acoustic
# 15   31       0  Classical
# 16   34       0  Classical
# 17   35       0  Classical

# %% [markdown]
# # Assistant
# This error occurs because `joblib` has been removed from `sklearn.externals` in newer versions of scikit-learn. The `sklearn.externals.joblib` was deprecated and eventually removed, and you should now use the standalone `joblib` package instead.
#
# Would you like me to provide the corrected code?

# %%
X= music_data.drop(columns =['genre'])
y = music_data['genre']

# %%
# model = DecisionTreeClassifier()
# model.fit(X,y)
# predictions = model.predict([ [21,1],[22,0] ])

# %% [markdown]
# ### Calculating the accuracy

# %%
X_train, X_test, y_train, y_test = train_test_split (X, y, test_size = 0.2)

# %%
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions) 
score
# Out:
# 0.5

# %% [markdown]
# Persisting Models

# %%
joblib.dump(model,'music-recommender.joblib')
# Out:
# ['music-recommender.joblib']

# %%
# model2 = joblib.load('music-recommender.joblib')
# predictions2 = model2.predict([[21,1]])
# predictions2

# %% [markdown]
# Visualization

# %%
tree.export_graphviz(model, out_file='music-recommender.dot', 
                     feature_names=['age','gender'], 
                     class_names=sorted(y.unique()), 
                     label='all',
                     rounded = True,
                     filled = True)
